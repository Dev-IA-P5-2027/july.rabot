# %% [markdown]
# # **1. Import the necessary lib**

# %%
# pip install contractions emoji autocorrect

# %%
# pip install nltk

# %%
import nltk
import string
import re

# %%
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %% [markdown]
# # **2. Text Normalization**

# %%
# lowercasing
def text_lowercase(texte):
    return texte.lower()

# %%
input_text = "Hey, did you know that the summer break is coming? Amazing right !! It's only 5 more days !!"
text_lowercase(input_text)
# Out:
# "hey, did you know that the summer break is coming? amazing right !! it's only 5 more days !!"

# %%
# 2 Handling Contractions
import contractions

def fix_contractions(data):
    expanded_corpus = [contractions.fix(text) for text in data]
    return expanded_corpus

# %%
corpus = [
    "I can't wait for the new season of my favorite show!",
    "Lemme know when you're ready.",
    "Let's go!",
    "Nothing gonna change my love for you"
]

fix_contractions(corpus)
# Out:
# ['I cannot wait for the new season of my favorite show!',
#  'Let Me know when you are ready.',
#  'Let us go!',
#  'Nothing going to change my love for you']

# %%
# Spell checking

from autocorrect import Speller

def correct_with_autocorrect(text, lang='en'):
    """Correct spelling using autocorrect library for English."""
    spell = Speller(lang=lang)
    return spell(text)

# %%
# Example qui marche pas

text = "I wnt to the library to reed a bok."
corrected = correct_with_autocorrect(text)
print(f"Original : {text}")
print(f"Corrected : {corrected}")
# Out:
# Original : I wnt to the library to reed a bok.
# Corrected : I wnt to the library to reed a bok.

# %%
# Exemple qui fonctionne
text ="I'm not sleapy and tehre is no place I'm giong to."
corrected = correct_with_autocorrect(text)
print(f"Original : {text}")
print(f"Corrected : {corrected}")
# Out:
# Original : I'm not sleapy and tehre is no place I'm giong to.
# Corrected : I'm not sleepy and there is no place I'm going to.

# %%
pip install textblob
# Out:
# Requirement already satisfied: textblob in c:\users\user\onedrive\documents\github\dev_ia\july.rabot\ning\ning\ningproject\lib\site-packages (0.19.0)
# Requirement already satisfied: nltk>=3.9 in c:\users\user\onedrive\documents\github\dev_ia\july.rabot\ning\ning\ningproject\lib\site-packages (from textblob) (3.9.3)
# Requirement already satisfied: click in c:\users\user\onedrive\documents\github\dev_ia\july.rabot\ning\ning\ningproject\lib\site-packages (from nltk>=3.9->textblob) (8.3.1)
# Requirement already satisfied: joblib in c:\users\user\onedrive\documents\github\dev_ia\july.rabot\ning\ning\ningproject\lib\site-packages (from nltk>=3.9->textblob) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\user\onedrive\documents\github\dev_ia\july.rabot\ning\ning\ningproject\lib\site-packages (from nltk>=3.9->textblob) (2026.2.28)
# Requirement already satisfied: tqdm in c:\users\user\onedrive\documents\github\dev_ia\july.rabot\ning\ning\ningproject\lib\site-packages (from nltk>=3.9->textblob) (4.67.3)
# Requirement already satisfied: colorama in c:\users\user\onedrive\documents\github\dev_ia\july.rabot\ning\ning\ningproject\lib\site-packages (from click->nltk>=3.9->textblob) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Marche bof bof cette librairie

from textblob import TextBlob

def correct_with_textblob(text):
    blob = TextBlob(text)
    corrected = blob.correct()
    return str(corrected)


text = "I wnt to the library to reed a bok."
corrected = correct_with_textblob(text)
print(f"Original : {text}")
print(f"Corrected : {corrected}")
# Out:
# Original : I wnt to the library to reed a bok.
# Corrected : I went to the library to reed a boy.

# %%
from textblob import TextBlob

def correct_with_textblob(text):
    blob = TextBlob(text)
    corrected = blob.correct()
    return str(corrected)


text = "I'm not sleapy and tehre is no place I'm giong to."
corrected = correct_with_textblob(text)
print(f"Original : {text}")
print(f"Corrected : {corrected}")
# Out:
# Original : I'm not sleapy and tehre is no place I'm giong to.
# Corrected : I'm not sleepy and there is no place I'm going to.

# %% [markdown]
# # **3. Standardizing accent characters**

# %%
import unicodedata

def standardize_accented_chars(text):
    return unicodedata.normalize('NFKD', text).encode('ascii', 'ignore').decode('utf-8', 'ignore')

# %%
input_text = "Somë words such as résumé, café, protest, divorcé, coördinate, exposé, latté."
print(standardize_accented_chars(input_text))
# Out:
# Some words such as resume, cafe, protest, divorce, coordinate, expose, latte.

# %% [markdown]
# # **4. Noise Removal**

# %%
# 1 Removing html tags

def remove_html_tagst_regex(text):
    """Remove HTML tags using regular expression"""
    clean = re.compile('<.*?>')
    return re.sub(clean, '', text)

# %%
html_text = "<p>Hello, <b>world</b>!</p> <a href='#'>Click here</a>"
clean_text = remove_html_tagst_regex(html_text)
print(clean_text)
# Out:
# Hello, world! Click here

# %%
# 2 Removing numbers/digits
def remove_numbers(text):
    result = re.sub(r'\d+', '<phone number>', text)
    return result

# %%
# 2 Removing numbers/digits
def remove_numbers(text):
    result = re.sub(r'\d{7,}', '<phone number>', text)
    return result

# %%
input_text = "Her phone number is 0123456789, and my phone number is 0987654321"
remove_numbers(input_text)
# Out:
# 'Her phone number is <phone number>, and my phone number is <phone number>'

# %% [markdown]
# We can also convert the numbers into words. This can be done by using the inflect library

# %%
pip install inflect
# Out:
# Collecting inflect
#   Downloading inflect-7.5.0-py3-none-any.whl.metadata (24 kB)
# Collecting more_itertools>=8.5.0 (from inflect)
#   Downloading more_itertools-10.8.0-py3-none-any.whl.metadata (39 kB)
# Collecting typeguard>=4.0.1 (from inflect)
#   Downloading typeguard-4.5.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting typing_extensions>=4.14.0 (from typeguard>=4.0.1->inflect)
#   Using cached typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Downloading inflect-7.5.0-py3-none-any.whl (35 kB)
# Downloading more_itertools-10.8.0-py3-none-any.whl (69 kB)
# Downloading typeguard-4.5.1-py3-none-any.whl (36 kB)
# Using cached typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Installing collected packages: typing_extensions, more_itertools, typeguard, inflect
#
#    -------------------- ------------------- 2/4 [typeguard]
#    ---------------------------------------- 4/4 [inflect]
#
# Successfully installed inflect-7.5.0 more_itertools-10.8.0 typeguard-4.5.1 typing_extensions-4.15.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# 3. Convert the numbers into words

import inflect

p = inflect.engine()

#convert numbers into words
def convert_number(text):
    #split string into list of words
    temp_str = text.split()
    #initialise empty list
    new_string = []

    for word in temp_str:
        # if word is a digit, convert the digit
        # to numbers and append into the new_string list
        if word.isdigit():
            temp=p.number_to_words(word)
            new_string.append(temp)
        # append the word as it is
        else:
            new_string.append(word)

    # join the words of the new_string to form a string
    temp_str = ' '.join(new_string)
    return temp_str


input_text = 'There are 3 balls in this bag, and 12 in the other one.'
convert_number(input_text)
# Out:
# 'There are three balls in this bag, and twelve in the other one.'

# %%
# 4. Removing punctuation et special characters

regular_punct = list(string.punctuation)
print(regular_punct)
# Out:
# ['!', '"', '#', '$', '%', '&', "'", '(', ')', '*', '+', ',', '-', '.', '/', ':', ';', '<', '=', '>', '?', '@', '[', '\\', ']', '^', '_', '`', '{', '|', '}', '~']

# %%
def remove_punctuation(text, punct_list):
    for punc in punct_list:
        if punc in text:
            text = text.replace(punc, '')
    return text.strip()

remove_punctuation("Hey @Lisa, did you know that the summer break is coming ? Amazing right !! It's only 5 more days !!", regular_punct)
# Out:
# 'Hey Lisa did you know that the summer break is coming  Amazing right  Its only 5 more days'

# %%
# 5. Handling double whitespace from text
def remove_whitespace(text):
        return " ".join(text.split())

input_str = "we don't need the given    questions."
remove_whitespace(input_str)
# Out:
# "we don't need the given questions."

# %%
# 6. Handling emoji/emoticon ---> for sentiment analysis, emoji/emoticon is usually not removed

def remove_emojis_regex(text):
    """Remove emojis using Unicode emoji ranges."""
    #Unicode ranges for emojis
    emoji_pattern = re.compile("["
        u"\U0001F600-\U0001F64F" #emotion
        u"\U0001F3006\U0001F5FF"
        u"\U0001F680-\U0001F6FF"
        u"\U0001F1E0-\U0001F1FF"
        u"\U00002702-\U000027B2"
        u"\U000024C2-\U0001F251"
        u"\U0001f926-\U0001f937"
        u"\U00010000-\U0010ffff"
        "]+", flags=re.UNICODE)
    
    return emoji_pattern.sub(r'', text)

# %%
# Example
text = "Hello! ☺️ How are you? 🎉 I'm in NYC 🏴‍☠️"
clean_text = remove_emojis_regex(text)
print(clean_text)
# Out:
# Hello!  How are you?  I'm in NYC ‍

# %%
import emoji 


def remove_emojis_emoji_library(text):
    """Remove emojis using the emoji library."""
    return emoji.replace_emoji(text, replace = '')


def replace_emojis_with_text(text):
    """Replace emojis with their text description."""
    return emoji.demojize(text)


#Examples
text = "I love Python ! 🐍❤️ Let's code ! 💻"

print(remove_emojis_emoji_library(text))
print(replace_emojis_with_text(text))
# Out:
# I love Python !  Let's code !
# I love Python ! :snake::red_heart: Let's code ! :laptop:

# %%
import emoji 


def remove_emojis_emoji_library(text):
    """Remove emojis using the emoji library."""
    return emoji.replace_emoji(text, replace = '')


def replace_emojis_with_text(text):
    """Replace emojis with their text description."""
    return emoji.demojize(text)


#Examples
text = "I love Python ! 🩻🖤 Let's code ! 🏴‍☠️"

print(remove_emojis_emoji_library(text))
print(replace_emojis_with_text(text))
# Out:
# I love Python !  Let's code !
# I love Python ! :x-ray::black_heart: Let's code ! :pirate_flag:

# %%
# 7. Removal of URLs or other irrelevant hints

#Define a regex pattern to match URLs 
url_pattern = re.compile(r'https?://\S+')

#Define a function to remove URLs from text
def remove_urls(text):
    return url_pattern.sub('', text) #replace the url with word "this link"

text = "Visit https://www.google.com for more information."

remove_urls(text)
# Out:
# 'Visit  for more information.'

# %%
url_pattern = []
url_pattern.append(re.compile(r'https:?//\S+'))
url_pattern.append(re.compile(r'http:?//\S+'))
url_pattern.append(re.compile(r'www.\S+'))

def remove_urls2(text):
    for pattern in url_pattern:
        text=pattern.sub('<this link>', text)
    return text


input_text = "Visit the following link : www.google.com"
print(remove_urls2(input_text))
# Out:
# Visit the following link : <this link>

# %% [markdown]
# # **5. Tokenization**

# %% [markdown]
# In NLP tokenization is the text preprocessing task of breaking up text into smaller components of text (know as tokens)

# %%
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
nltk.download('punkt') # This line is needed to download the necessary datasets for tokenization

text = "This is a text to tokenize"
tokenized = nltk.word_tokenize(text)

print("Resultat from tokenization:", tokenized)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# Resultat from tokenization: ['This', 'is', 'a', 'text', 'to', 'tokenize']
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# [nltk_data] Zip Slip blocked: punkt/

# %% [markdown]
# # **6. Stopwords removal**

# %% [markdown]
# Stopwords are words that do not contribute to the meaning of a sentence. Hence, they can safely be removed without causing any change in the meaning of the sentence. The NLTK library has a set of stopwords and we can use these to remove stopwords from our text and return a list of word tokens.

# %%
# Stop words removal
from nltk.corpus import stopwords
nltk.download('stopwords')


stop_words = set(stopwords.words('english'))
print(stop_words)
# Out:
# {'had', 'before', 'too', 'didn', 'hers', 'mustn', 'so', 'ourselves', 'not', "hasn't", 'been', "she's", "we've", 'what', 'a', 'y', 'your', 'further', "you'd", 'have', 'shan', "they're", 'yours', 'me', 'wasn', 'nor', 'with', 'themselves', 'do', 'the', 'more', 'after', 'she', 'up', 'we', "i've", 'then', 'where', "we're", 'has', 'm', "she'd", 'in', 'under', 'those', "aren't", 'on', 'herself', 'which', 'few', 'because', 'as', 'that', "we'll", 'each', 'these', "needn't", 'his', 'being', 'again', "didn't", 'own', "you'll", "hadn't", "i'd", 'if', 'hasn', "i'm", 'most', 'my', "they'd", 'at', "couldn't", 'you', 'mightn', 'who', 'whom', 'hadn', 'myself', "wouldn't", 'down', 'to', "you've", "wasn't", "i'll", "he'll", 'there', 'shouldn', 'off', 'than', "it's", 'weren', 'no', 'should', 'yourselves', "won't", 'this', "shouldn't", 'until', 'through', "don't", "should've", 'but', 'he', 'is', 'o', 'while', 'aren', 'd', 'can', "mightn't", 'out', 'were', 'they', 'don', "she'll", 'just', "you're", 're', 'only', 'our', 'was', "shan't", 'some', 'having', 'against', 'any', "he'd", 'them', 'here', 'all', 'and', 'yourself', 'above', 'into', 'be', 'why', "he's", 'did', 'itself', 'won', 'about', 'needn', "we'd", 'an', 'both', "it'd", 'between', 'ma', 'ours', 'himself', 've', 'for', 'll', "haven't", "mustn't", "isn't", 'during', 'how', 'its', 'once', 'haven', 'of', 'their', 'very', 'him', 'am', 'when', 'doing', "they'll", 's', 'from', "that'll", 'wouldn', 'doesn', "it'll", 'or', 'are', 'now', 'it', 't', 'below', "they've", 'her', 'by', "weren't", 'isn', 'over', 'couldn', 'ain', "doesn't", 'same', 'will', 'does', 'other', 'such', 'i', 'theirs'}
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# [nltk_data] Zip Slip blocked: stopwords/

# %%
# Costumize the stopwords set. For example you want to add new word 'test' in it
stop_words.add('test')

# %%
print(stop_words)
# Out:
# {'had', 'before', 'too', 'didn', 'hers', 'mustn', 'so', 'ourselves', 'not', "hasn't", 'been', "she's", "we've", 'what', 'a', 'y', 'your', 'further', "you'd", 'have', 'shan', "they're", 'yours', 'me', 'wasn', 'nor', 'with', 'themselves', 'do', 'the', 'more', 'after', 'she', 'up', 'we', "i've", 'then', 'where', "we're", 'has', 'm', "she'd", 'in', 'under', 'those', "aren't", 'on', 'herself', 'which', 'few', 'because', 'as', 'that', "we'll", 'each', 'these', "needn't", 'his', 'being', 'again', "didn't", 'own', "you'll", "hadn't", "i'd", 'if', 'hasn', "i'm", 'most', 'my', "they'd", 'at', "couldn't", 'you', 'mightn', 'who', 'whom', 'hadn', 'myself', "wouldn't", 'test', 'down', 'to', "you've", "wasn't", "i'll", "he'll", 'there', 'shouldn', 'off', 'than', "it's", 'weren', 'no', 'should', 'yourselves', "won't", 'this', "shouldn't", 'until', 'through', "don't", "should've", 'but', 'he', 'is', 'o', 'while', 'aren', 'd', 'can', "mightn't", 'out', 'were', 'they', 'don', "she'll", 'just', "you're", 're', 'only', 'our', 'was', "shan't", 'some', 'having', 'against', 'any', "he'd", 'them', 'here', 'all', 'and', 'yourself', 'above', 'into', 'be', 'why', "he's", 'did', 'itself', 'won', 'about', 'needn', "we'd", 'an', 'both', "it'd", 'between', 'ma', 'ours', 'himself', 've', 'for', 'll', "haven't", "mustn't", "isn't", 'during', 'how', 'its', 'once', 'haven', 'of', 'their', 'very', 'him', 'am', 'when', 'doing', "they'll", 's', 'from', "that'll", 'wouldn', 'doesn', "it'll", 'or', 'are', 'now', 'it', 't', 'below', "they've", 'her', 'by', "weren't", 'isn', 'over', 'couldn', 'ain', "doesn't", 'same', 'will', 'does', 'other', 'such', 'i', 'theirs'}

# %%
# # Stop words removal
# from nltk.corpus import stopwords
# nltk.download('stopwords')


# stop_words = set(stopwords.words('french'))
# print(stop_words)

# %%
# The required librairies

import nltk 
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# Download the necessary NLTK datasets
nltk.download('punkt')
nltk.download('stopwords')

#remove stopwords function
def remove_stopwords(text):
    stop_words = set(stopwords.words("english"))
    word_tokens = word_tokenize(text)

    #Filter out the stopwords
    filtered_text = [word for word in word_tokens if word.lower() not in stop_words]

    return filtered_text


example_text = "This is a sample sentence and we are going to remove the stopwords from this"
print("Before stopwords : ", example_text)
print("After removing stopwords : ", remove_stopwords(example_text))
# Out:
# Before stopwords :  This is a sample sentence and we are going to remove the stopwords from this
# After removing stopwords :  ['sample', 'sentence', 'going', 'remove', 'stopwords']
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# # **7. Stemming and Lemmatization**

# %%
from nltk.stem.porter import PorterStemmer
from nltk.tokenize import word_tokenize

# %%
# Stemming

from nltk.stem.porter import PorterStemmer
from nltk.tokenize import word_tokenize
stemmer = PorterStemmer()

#stem words in the list of tokenized words
def stem_words(text):
    word_tokens = word_tokenize(text)
    stems = [stemmer.stem(word) for word in word_tokens]
    return stems

text = "data science uses scientific methods algorihms and many types of processes"
stem_words(text)
# Out:
# ['data',
#  'scienc',
#  'use',
#  'scientif',
#  'method',
#  'algorihm',
#  'and',
#  'mani',
#  'type',
#  'of',
#  'process']

# %%
# Lemmatization using NLTK

import nltk
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize


#Download the necessary NLTK datasets
nltk.download('punkt')
nltk.download('wordnet')

#Initialize the WordNetLemmatizer

lemmatizer = WordNetLemmatizer()

#Function to lemmatize words in the list of tokenized words
def lemma_words(text):
    word_tokens = word_tokenize(text)
    lemmas = [lemmatizer.lemmatize(word) for word in word_tokens]
    return lemmas


#Example text

text = "The quick brown foxes are jumping over the lazy dogs."
print(lemma_words(text))
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# ['The', 'quick', 'brown', 'fox', 'are', 'jumping', 'over', 'the', 'lazy', 'dog', '.']

# %%
pip install spacy
# Out:
# Requirement already satisfied: spacy in c:\users\user\onedrive\documents\github\dev_ia\july.rabot\ning\ning\ningproject\lib\site-packages (3.8.11)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\user\onedrive\documents\github\dev_ia\july.rabot\ning\ning\ningproject\lib\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\user\onedrive\documents\github\dev_ia\july.rabot\ning\ning\ningproject\lib\site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\user\onedrive\documents\github\dev_ia\july.rabot\ning\ning\ningproject\lib\site-packages (from spacy) (1.0.15)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\user\onedrive\documents\github\dev_ia\july.rabot\ning\ning\ningproject\lib\site-packages (from spacy) (2.0.13)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\user\onedrive\documents\github\dev_ia\july.rabot\ning\ning\ningproject\lib\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: thinc<8.4.0,>=8.3.4 in c:\users\user\onedrive\documents\github\dev_ia\july.rabot\ning\ning\ningproject\lib\site-packages (from spacy) (8.3.10)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\user\onedrive\documents\github\dev_ia\july.rabot\ning\ning\ningproject\lib\site-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\user\onedrive\documents\github\dev_ia\july.rabot\ning\ning\ningproject\lib\site-packages (from spacy) (2.5.2)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\user\onedrive\documents\github\dev_ia\july.rabot\ning\ning\ningproject\lib\site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.4.2 in c:\users\user\onedrive\documents\github\dev_ia\july.rabot\ning\ning\ningproject\lib\site-packages (from spacy) (0.4.3)
# Requirement already satisfied: typer-slim<1.0.0,>=0.3.0 in c:\users\user\onedrive\documents\github\dev_ia\july.rabot\ning\ning\ningproject\lib\site-packages (from spacy) (0.24.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\user\onedrive\documents\github\dev_ia\july.rabot\ning\ning\ningproject\lib\site-packages (from spacy) (4.67.3)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\user\onedrive\documents\github\dev_ia\july.rabot\ning\ning\ningproject\lib\site-packages (from spacy) (2.4.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\user\onedrive\documents\github\dev_ia\july.rabot\ning\ning\ningproject\lib\site-packages (from spacy) (2.32.5)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\user\onedrive\documents\github\dev_ia\july.rabot\ning\ning\ningproject\lib\site-packages (from spacy) (2.12.5)
# Requirement already satisfied: jinja2 in c:\users\user\onedrive\documents\github\dev_ia\july.rabot\ning\ning\ningproject\lib\site-packages (from spacy) (3.1.6)
# Requirement already satisfied: setuptools in c:\users\user\onedrive\documents\github\dev_ia\july.rabot\ning\ning\ningproject\lib\site-packages (from spacy) (82.0.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\onedrive\documents\github\dev_ia\july.rabot\ning\ning\ningproject\lib\site-packages (from spacy) (26.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\user\onedrive\documents\github\dev_ia\july.rabot\ning\ning\ningproject\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\user\onedrive\documents\github\dev_ia\july.rabot\ning\ning\ningproject\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.41.5)
# Requirement already satisfied: typing-extensions>=4.14.1 in c:\users\user\onedrive\documents\github\dev_ia\july.rabot\ning\ning\ningproject\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\user\onedrive\documents\github\dev_ia\july.rabot\ning\ning\ningproject\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\user\onedrive\documents\github\dev_ia\july.rabot\ning\ning\ningproject\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4.5)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\onedrive\documents\github\dev_ia\july.rabot\ning\ning\ningproject\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\user\onedrive\documents\github\dev_ia\july.rabot\ning\ning\ningproject\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\onedrive\documents\github\dev_ia\july.rabot\ning\ning\ningproject\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2026.2.25)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in c:\users\user\onedrive\documents\github\dev_ia\july.rabot\ning\ning\ningproject\lib\site-packages (from thinc<8.4.0,>=8.3.4->spacy) (1.3.3)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\user\onedrive\documents\github\dev_ia\july.rabot\ning\ning\ningproject\lib\site-packages (from thinc<8.4.0,>=8.3.4->spacy) (0.1.5)
# Requirement already satisfied: colorama in c:\users\user\onedrive\documents\github\dev_ia\july.rabot\ning\ning\ningproject\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.6)
# Requirement already satisfied: typer>=0.24.0 in c:\users\user\onedrive\documents\github\dev_ia\july.rabot\ning\ning\ningproject\lib\site-packages (from typer-slim<1.0.0,>=0.3.0->spacy) (0.24.1)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in c:\users\user\onedrive\documents\github\dev_ia\july.rabot\ning\ning\ningproject\lib\site-packages (from weasel<0.5.0,>=0.4.2->spacy) (0.23.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in c:\users\user\onedrive\documents\github\dev_ia\july.rabot\ning\ning\ningproject\lib\site-packages (from weasel<0.5.0,>=0.4.2->spacy) (7.5.1)
# Requirement already satisfied: wrapt in c:\users\user\onedrive\documents\github\dev_ia\july.rabot\ning\ning\ningproject\lib\site-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.4.2->spacy) (2.1.2)
# Requirement already satisfied: click>=8.2.1 in c:\users\user\onedrive\documents\github\dev_ia\july.rabot\ning\ning\ningproject\lib\site-packages (from typer>=0.24.0->typer-slim<1.0.0,>=0.3.0->spacy) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\user\onedrive\documents\github\dev_ia\july.rabot\ning\ning\ningproject\lib\site-packages (from typer>=0.24.0->typer-slim<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in c:\users\user\onedrive\documents\github\dev_ia\july.rabot\ning\ning\ningproject\lib\site-packages (from typer>=0.24.0->typer-slim<1.0.0,>=0.3.0->spacy) (14.3.3)
# Requirement already satisfied: annotated-doc>=0.0.2 in c:\users\user\onedrive\documents\github\dev_ia\july.rabot\ning\ning\ningproject\lib\site-packages (from typer>=0.24.0->typer-slim<1.0.0,>=0.3.0->spacy) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\user\onedrive\documents\github\dev_ia\july.rabot\ning\ning\ningproject\lib\site-packages (from rich>=12.3.0->typer>=0.24.0->typer-slim<1.0.0,>=0.3.0->spacy) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\user\onedrive\documents\github\dev_ia\july.rabot\ning\ning\ningproject\lib\site-packages (from rich>=12.3.0->typer>=0.24.0->typer-slim<1.0.0,>=0.3.0->spacy) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\user\onedrive\documents\github\dev_ia\july.rabot\ning\ning\ningproject\lib\site-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer>=0.24.0->typer-slim<1.0.0,>=0.3.0->spacy) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\user\onedrive\documents\github\dev_ia\july.rabot\ning\ning\ningproject\lib\site-packages (from jinja2->spacy) (3.0.3)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !python -m spacy download en_core_web_sm
# Out:
# Collecting en-core-web-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.8.0/en_core_web_sm-3.8.0-py3-none-any.whl (12.8 MB)
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      - -------------------------------------- 0.5/12.8 MB 7.2 MB/s eta 0:00:02
#      ---------------- ----------------------- 5.2/12.8 MB 20.9 MB/s eta 0:00:01
#      ----------------------------------- --- 11.5/12.8 MB 24.6 MB/s eta 0:00:01
#      ---------------------------------------- 12.8/12.8 MB 24.7 MB/s  0:00:00
# Installing collected packages: en-core-web-sm
# Successfully installed en-core-web-sm-3.8.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import spacy 

#Load the spaCy English model
nlp = spacy.load('en_core_web_sm')

#Define a sample text
text = "The quick brown foxes are jumping over the lazy dogs"

#Process the text using spaCy 
doc = nlp(text)

#Extract lemmatized tokens
lemmatized_tokens = [token.lemma_ for token in doc]

#Join the lemmatized tokens into a sentence
lemmatized_text = ' '.join(lemmatized_tokens)

#Print the original and lemmatized text
print("Original Text :", text)
print("Lemmatized Text:", lemmatized_text)
# Out:
# Original Text : The quick brown foxes are jumping over the lazy dogs
# Lemmatized Text: the quick brown fox be jump over the lazy dog

# %% [markdown]
# # **Coding Exercice !**
